# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from tslearn.clustering import TimeSeriesKMeans
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, \
    TimeSeriesResampler
from tslearn.clustering import silhouette_score
import seaborn as sns
from tslearn.utils import to_time_series_dataset
from tslearn.clustering import silhouette_score

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score 
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.cluster import KElbowVisualizer

from imblearn.over_sampling import RandomOverSampler
from collections import Counter

import keras
#from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf

from imblearn.over_sampling import SMOTE

from mpl_toolkits.mplot3d import Axes3D

# %%
from print_versions import print_versions
import sys
import sklearn
import matplotlib
print_versions(globals())
print(sys. version)
# Out:
# pandas==2.2.2
# numpy==1.26.4
# tslearn==0.6.3
# seaborn==0.13.2
# yellowbrick==1.5
# keras==3.9.2
# tensorflow==2.19.0
# sklearn==1.5.1
# matplotlib==3.9.2
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# # Functions

# %%
def load_labels(link, method, abm, k):
    labels_df = pd.read_json(link, lines=True) 
    row = labels_df[(labels_df["method"] == method) &
                    (labels_df["abm"] == abm) &
                    (labels_df["k"] == k)] 
    if not row.empty:
        labels = row.iloc[0]["labels"]
        print(f"Loaded {len(labels)} labels for {method.upper()} ({abm}), k={k}")
    else:
        print("No matching entry found.")
    return labels

# %%
def knn_cluster(inputs, labels):
    X_train, X_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.1, random_state = 1)
    knn_clf=KNeighborsClassifier()
    knn_clf.fit(X_train,y_train)
    ypred=knn_clf.predict(X_test)
    result = confusion_matrix(y_test, ypred)
    print("Confusion Matrix:")
    print(result)
    report = classification_report(y_test, ypred)
    print("Report:",)
    print (report)
    acc = accuracy_score(y_test,ypred)
    print("Accuracy:",acc)

# %%
def mlp_baseline(inputs, labels, k):
    X_train, X_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.1, random_state = 1)
    X = X_train
    Y = y_train
    dummy_y = to_categorical(Y)
    
    model = Sequential()
    model.add(Dense(8, input_shape=(X.shape[1],), activation='relu'))
    model.add(Dense(7, activation='softmax'))
    model.summary()
    
    model.compile(optimizer='rmsprop', 
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
     
    es = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                       mode='min',
                                       patience=10, 
                                       restore_best_weights=True)
    
    history = model.fit(X,
                        dummy_y,
                        callbacks=[es],
                        epochs=500, 
                        batch_size=10,
                        shuffle=True,
                        validation_split=0.2,
                        verbose=1)
    history_dict = history.history
    
    acc = history_dict['accuracy']
    val_acc = history_dict['val_accuracy']
    
    loss = history_dict['loss']
    val_loss = history_dict['val_loss']
    
    epochs = range(1, len(acc) + 1)
    
    plt.plot(epochs, acc, 'r', label='Training accuracy')
    
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    preds = model.predict(X) 
    print(preds[0]) 
    print(np.sum(preds[0])) 
    
    matrix = confusion_matrix(dummy_y.argmax(axis=1), preds.argmax(axis=1))
    matrix
    print(classification_report(dummy_y.argmax(axis=1), preds.argmax(axis=1)))
    preds = model.predict(X_test) 
    print("Report:",)
    print(classification_report(y_test, preds.argmax(axis=1)))
    acc = accuracy_score(y_test,preds.argmax(axis=1))
    print("Accuracy:",acc)

# %%
def mlp_improved(inputs, labels, k):
    X_train_raw, X_val, y_train_raw, y_val = train_test_split(
        inputs, labels, 
        test_size=0.2, 
        stratify=labels,
        random_state=42)
    scaler = StandardScaler()
    X_train_res = scaler.fit_transform(X_train_raw)
    X_val_scaled = scaler.transform(X_val)
    
    num_classes = len(pd.Series(labels).unique())
    y_train_cat = to_categorical(y_train_raw, num_classes)
    y_val_cat   = to_categorical(y_val, num_classes)
    
    num_classes = k
    
    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train_res.shape[1],)),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    es = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )
    
    history = model.fit(
        X_train_res,
        y_train_cat,
        validation_data=(X_val_scaled, y_val_cat),
        epochs=200,
        batch_size=512,
        callbacks=[es],
        shuffle=True,
        verbose=1
    )
    
    val_preds = model.predict(X_val_scaled).argmax(axis=1)
    
    print(confusion_matrix(y_val, val_preds))
    print(classification_report(y_val, val_preds, digits=4))
    return X_train_raw, X_val, y_train_raw, y_val, val_preds

# %%
def mlp_improved_smote(inputs, labels, k):
    X_train_raw, X_val, y_train_raw, y_val = train_test_split(
        inputs, labels, 
        test_size=0.2, 
        stratify=labels,
        random_state=42)

    sm = SMOTE(k_neighbors=3, random_state=42)
    X_train_res, y_train_res = sm.fit_resample(X_train_raw, y_train_raw)

    scaler = StandardScaler()
    X_train_res = scaler.fit_transform(X_train_res)
    X_val_scaled = scaler.transform(X_val)
    
    
    num_classes = len(pd.Series(labels).unique())
    y_train_cat = to_categorical(y_train_res, num_classes)
    y_val_cat   = to_categorical(y_val, num_classes)
    
    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train_res.shape[1],)),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    es = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )
    
    history = model.fit(
        X_train_res,
        y_train_cat,
        validation_data=(X_val_scaled, y_val_cat),
        epochs=200,
        batch_size=512,
        callbacks=[es],
        shuffle=True,
        verbose=1
    )
    
    val_preds = model.predict(X_val_scaled).argmax(axis=1)
    
    print(confusion_matrix(y_val, val_preds))
    print(classification_report(y_val, val_preds, digits=4))
    return X_train_raw, X_val, y_train_raw, y_val, val_preds

# %% [markdown]
# # Bank Reserves

# %%
br_inputs = pd.read_csv("~/Desktop/TS-Clustering/SimData/bank_reserves_inputs.csv", header=None)
br_inputs_arr = br_inputs.iloc[:, 0].to_numpy()

# %%
labels = load_labels("~/Desktop/TS-Clustering/daep_labels_agglom_centroid.ndjson", "daep", "BR", 7)
# Out:
# Loaded 100000 labels for DAEP (BR), k=7

# %%
pd.Series(labels).value_counts()
# Out:
# 2    43360
# 3    27768
# 1    10599
# 6     5135
# 5     4659
# 0     4316
# 4     4163
# Name: count, dtype: int64

# %%
counts = pd.Series(labels).value_counts().sort_index()

plt.figure(figsize=(8,5))
plt.barh(counts.index.astype(str), counts.values, color='steelblue')

plt.xlabel("Count")
plt.ylabel("Class Label")
plt.title("Label Distribution")

# Add value labels at end of each bar
for idx, value in enumerate(counts.values):
    plt.text(value + 0.01 * max(counts.values),  # slightly to the right
             idx,
             str(value),
             va='center',
             fontsize=10)

plt.tight_layout()
plt.savefig('br_motif_counts.png')
plt.show()

# %%
kde_plt = sns.displot(x=br_inputs_arr, hue=labels, kind="kde", palette=sns.color_palette("hls", 7))
kde_plt.savefig("br_kde.png")

# %%
knn_cluster(br_inputs, labels)
# Out:
# Confusion Matrix:
# [[ 298    0    0    0   69   64    0]
#  [   0  881    0   87    1    0   75]
#  [   0    0 4264    0    0   62    0]
#  [   0   99    0 2735    0    0    0]
#  [  68    0    0    0  271    0   77]
#  [  49    0   92    0    0  297    0]
#  [   2   94    0    0   73    0  342]]
# Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.69      0.70       431
#            1       0.82      0.84      0.83      1044
#            2       0.98      0.99      0.98      4326
#            3       0.97      0.97      0.97      2834
#            4       0.65      0.65      0.65       416
#            5       0.70      0.68      0.69       438
#            6       0.69      0.67      0.68       511
#
#     accuracy                           0.91     10000
#    macro avg       0.79      0.78      0.79     10000
# weighted avg       0.91      0.91      0.91     10000
#
# Accuracy: 0.9088

# %%
#mlp_baseline(br_inputs, labels, 7)

# %%
X_train_raw, X_val, y_train_raw, y_val, val_preds = mlp_improved(br_inputs, labels, 7)
# Out:
# Epoch 1/200
# C:\Users\Maria\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6768 - loss: 1.0145 - val_accuracy: 0.7115 - val_loss: 0.6017
# Epoch 2/200
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7724 - loss: 0.4991 - val_accuracy: 0.8637 - val_loss: 0.3829
# Epoch 3/200
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8796 - loss: 0.3378 - val_accuracy: 0.9106 - val_loss: 0.2735
# Epoch 4/200
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9005 - loss: 0.2709 - val_accuracy: 0.9166 - val_loss: 0.2317
# Epoch 5/200
# ...

# %%
X_train_raw_sm, X_val_sm, y_train_raw_sm, y_val_sm, val_pred_sm = mlp_improved_smote(br_inputs, labels, 7)
# Out:
# Epoch 1/200
# C:\Users\Maria\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6919 - loss: 0.8547 - val_accuracy: 0.8923 - val_loss: 0.2541
# Epoch 2/200
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8105 - loss: 0.4567 - val_accuracy: 0.9018 - val_loss: 0.2399
# Epoch 3/200
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8166 - loss: 0.4367 - val_accuracy: 0.9040 - val_loss: 0.2412
# Epoch 4/200
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8190 - loss: 0.4292 - val_accuracy: 0.9001 - val_loss: 0.2501
# Epoch 5/200
# ...

# %%
rf_prob = RandomForestClassifier(random_state=42)
rf_prob.fit(X_val, (val_preds ==  y_val).astype(int))
# Out:
# RandomForestClassifier(random_state=42)

# %%
prob_correct = rf_prob.predict_proba(X_val)[:,1]

# %%
plt.figure(figsize=(6,4))
plt.scatter(
    X_val.iloc[:,0],
    prob_correct,
    alpha = 0.5,
    s = 2
)
plt.xlabel("Reserve Pecentage")
plt.ylabel("P(Model correct | X)")
plt.title("Probability of Correct Classification Across Input Space")
plt.savefig("misclass_br.png")
plt.show()

# %% [markdown]
# # Epstein Civil Violence

# %%
ecv_inputs = pd.read_csv("~/Desktop/TS-Clustering/SimData/epsteinCV_inputs.csv", header=None, sep=' ')
ecv_inputs_arr = ecv_inputs.iloc[:, 0].to_numpy()

# %%
labels = load_labels("~/Desktop/TS-Clustering/daep_labels_agglom_centroid.ndjson", "daep", "ECV", 8)
# Out:
# Loaded 50362 labels for DAEP (ECV), k=8

# %%
pd.Series(labels).value_counts()
# Out:
# 0    42123
# 4     4692
# 2     1668
# 1      677
# 3      502
# 5      374
# 6      254
# 7       72
# Name: count, dtype: int64

# %%
counts = pd.Series(labels).value_counts().sort_index()

plt.figure(figsize=(8,5))
plt.barh(counts.index.astype(str), counts.values, color='steelblue')

plt.xlabel("Count")
plt.ylabel("Class Label")
plt.title("Label Distribution")

# Add value labels at end of each bar
for idx, value in enumerate(counts.values):
    plt.text(value + 0.01 * max(counts.values),  # slightly to the right
             idx,
             str(value),
             va='center',
             fontsize=10)

plt.tight_layout()
plt.savefig('ecv_motif_counts.png')
plt.show()

# %%
knn_cluster(ecv_inputs, labels)
# Out:
# Confusion Matrix:
# [[4162    1   35    6    4    0    1    1]
#  [   3   25   12    0   35    6    0    0]
#  [  48   11   92    1    5    7    0    0]
#  [  14    0    0   24    6    0    2    0]
#  [   5   17   11    3  426    0    0    0]
#  [   2   10   18    0    6    1    0    0]
#  [  13    0    1    8    2    0    4    0]
#  [   3    0    0    0    6    0    0    0]]
# Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      4210
#            1       0.39      0.31      0.34        81
#            2       0.54      0.56      0.55       164
#            3       0.57      0.52      0.55        46
#            4       0.87      0.92      0.89       462
#            5       0.07      0.03      0.04        37
#            6       0.57      0.14      0.23        28
#            7       0.00      0.00      0.00         9
#
#     accuracy                           0.94      5037
# ...

# %%
X_train_raw, X_val, y_train_raw, y_val, val_preds = mlp_improved(ecv_inputs, labels, 8)
# Out:
# Epoch 1/200
# C:\Users\Maria\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7660 - loss: 1.1305 - val_accuracy: 0.8366 - val_loss: 0.5374
# Epoch 2/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8645 - loss: 0.4828 - val_accuracy: 0.8863 - val_loss: 0.4177
# Epoch 3/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8843 - loss: 0.3975 - val_accuracy: 0.9040 - val_loss: 0.3462
# Epoch 4/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9006 - loss: 0.3342 - val_accuracy: 0.9152 - val_loss: 0.2889
# Epoch 5/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9119 - loss: 0.2869 - val_accuracy: 0.9260 - val_loss: 0.2478
# ...

# %%
X_train_raw_sm, X_val_sm, y_train_raw_sm, y_val_sm, val_pred_sm = mlp_improved_smote(ecv_inputs, labels, 8)
# Out:
# Epoch 1/200
# C:\Users\Maria\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 527/527 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5997 - loss: 1.0283 - val_accuracy: 0.8955 - val_loss: 0.2584
# Epoch 2/200
# 527/527 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7560 - loss: 0.6287 - val_accuracy: 0.9157 - val_loss: 0.2332
# Epoch 3/200
# 527/527 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7694 - loss: 0.5898 - val_accuracy: 0.9163 - val_loss: 0.2369
# Epoch 4/200
# 527/527 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7760 - loss: 0.5727 - val_accuracy: 0.9140 - val_loss: 0.2465
# Epoch 5/200
# ...

# %%
plt_kde = sns.displot(x=ecv_inputs[0], hue=labels, kind="kde", palette=sns.color_palette("hls", 8))
plt_kde.savefig('ecv_kde_0.png')

# %%
plt_kde = sns.displot(x=ecv_inputs[1], hue=labels, kind="kde", palette=sns.color_palette("hls", 8))
plt_kde.savefig('ecv_kde_1.png')

# %%
plt_kde = sns.displot(x=ecv_inputs[2], hue=labels, kind="kde", palette=sns.color_palette("hls", 8))
plt_kde.savefig('ecv_kde_2.png')

# %%
# --- Identify misclassifications ---
correct = (val_preds == y_val)
incorrect = ~correct

# --- Extract correct & incorrect points ---
Xc = X_val.to_numpy()[correct]
Xi = X_val.to_numpy()[incorrect]

fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')

# plot correct classifications
ax.scatter(Xc[:,0], Xc[:,1], Xc[:,2], 
           c='green', s=20, alpha=0.1, label='Correct')

# plot misclassifications
ax.scatter(Xi[:,0], Xi[:,1], Xi[:,2], 
           c='red', s=40, alpha=0.8, label='Misclassified')

ax.set_xlabel("Citizen Density")
ax.set_ylabel("Cop Density")
ax.set_zlabel("Perceived Legitimacy")
ax.set_title("3D Input Space: Correct vs Misclassified")

ax.legend()
ax.view_init(elev=15, azim=90)

plt.show()

# %%
# --- Identify misclassifications ---
correct = (val_preds == y_val)
incorrect = ~correct

# --- Extract correct & incorrect points ---
Xc = X_val.to_numpy()[correct]
Xi = X_val.to_numpy()[incorrect]

fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')

# plot correct classifications
ax.scatter(Xc[:,0], Xc[:,1], Xc[:,2], 
           c='green', s=20, alpha=0.1, label='Correct')

# plot misclassifications
ax.scatter(Xi[:,0], Xi[:,1], Xi[:,2], 
           c='red', s=40, alpha=0.8, label='Misclassified')

ax.set_xlabel("Citizen Density")
ax.set_ylabel("Cop Density")
ax.set_zlabel("Perceived Legitimacy")
ax.set_title("3D Input Space: Correct vs Misclassified")

ax.legend()
ax.view_init(elev=25, azim=180)

plt.show()

# %%
rf_prob = RandomForestClassifier(random_state=42)
rf_prob.fit(X_val, (val_pred_sm ==  y_val_sm).astype(int))
# Out:
# RandomForestClassifier(random_state=42)

# %%
prob_correct = rf_prob.predict_proba(X_val)[:,1]

# %%
X_arr = X_val.to_numpy()
pc = prob_correct  # array of shape (n,)

# --- Invert the transparency mapping ---
# low prob_correct → alpha near 1
# high prob_correct → alpha near 0.1
alpha = 0.2 + 0.8 * (1 - (pc - pc.min()) / (pc.max() - pc.min()))

# --- Map prob_correct to a colormap (color still encoded normally) ---
cmap = plt.get_cmap("viridis")
colors = cmap(pc)        # Nx4 RGBA
colors[:, 3] = alpha     # replace only the alpha channel

fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')

p = ax.scatter(
    X_arr[:,0], X_arr[:,1], X_arr[:,2],
    color=colors,
    s=20
)

ax.set_xlabel("Citizen Density")
ax.set_ylabel("Cop Density")
ax.set_zlabel("Perceived Legitimacy")
ax.set_title("3D Input Space (Low Confidence Points Stand Out)")

# colorbar for prob_correct (alpha ignored)
cb = fig.colorbar(plt.cm.ScalarMappable(cmap=cmap), ax=ax)
cb.set_label("Probability of Correct Classification")

ax.view_init(elev=15, azim=90)
plt.savefig("ecv_misclass_1.png")
plt.show()

# %%
X_arr = X_val.to_numpy()
pc = prob_correct  # array of shape (n,)

# --- Invert the transparency mapping ---
# low prob_correct → alpha near 1
# high prob_correct → alpha near 0.1
alpha = 0.2 + 0.8 * (1 - (pc - pc.min()) / (pc.max() - pc.min()))

# --- Map prob_correct to a colormap (color still encoded normally) ---
cmap = plt.get_cmap("viridis")
colors = cmap(pc)        # Nx4 RGBA
colors[:, 3] = alpha     # replace only the alpha channel

fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')

p = ax.scatter(
    X_arr[:,0], X_arr[:,1], X_arr[:,2],
    color=colors,
    s=20
)

ax.set_xlabel("Citizen Density")
ax.set_ylabel("Cop Density")
ax.set_zlabel("Perceived Legitimacy")
ax.set_title("3D Input Space (Low Confidence Points Stand Out)")

# colorbar for prob_correct (alpha ignored)
cb = fig.colorbar(plt.cm.ScalarMappable(cmap=cmap), ax=ax)
cb.set_label("Probability of Correct Classification")

ax.view_init(elev=25, azim=180)
plt.savefig('misclass_ecv_0.png')
plt.show()

# %% [markdown]
# # Forest Fire

# %%
ff_inputs = pd.read_csv("~/Desktop/TS-Clustering/SimData/forest_fire_inputs.csv", header=None, sep=' ')
ff_inputs_arr = ff_inputs.iloc[:, 0].to_numpy()

# %%
labels_df = pd.read_json("~/Desktop/TS-Clustering/daep_labels_agglom_centroid.ndjson", lines=True)
method = "daep"      
abm = "FF"          
k = 4                #

row = labels_df[(labels_df["method"] == method) &
                (labels_df["abm"] == abm) &
                (labels_df["k"] == k)]

if not row.empty:
    labels = row.iloc[0]["labels"]
    print(f"Loaded {len(labels)} labels for {method.upper()} ({abm}), k={k}")
else:
    print("No matching entry found.")
# Out:
# Loaded 100000 labels for DAEP (FF), k=4

# %%
pd.Series(labels).value_counts()
# Out:
# 1    58446
# 0    40415
# 2      724
# 3      415
# Name: count, dtype: int64

# %%
counts = pd.Series(labels).value_counts().sort_index()

plt.figure(figsize=(8,5))
plt.barh(counts.index.astype(str), counts.values, color='steelblue')

plt.xlabel("Count")
plt.ylabel("Class Label")
plt.title("Label Distribution")

# Add value labels at end of each bar
for idx, value in enumerate(counts.values):
    plt.text(value + 0.01 * max(counts.values),  # slightly to the right
             idx,
             str(value),
             va='center',
             fontsize=10)

plt.tight_layout()
plt.savefig('ff_motif_counts.png')
plt.show()

# %%
knn_cluster(ff_inputs, labels)
# Out:
# Confusion Matrix:
# [[4041   37   16    3]
#  [  32 5745    2    1]
#  [  52   15    4    2]
#  [  24   24    2    0]]
# Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4097
#            1       0.99      0.99      0.99      5780
#            2       0.17      0.05      0.08        73
#            3       0.00      0.00      0.00        50
#
#     accuracy                           0.98     10000
#    macro avg       0.53      0.51      0.51     10000
# weighted avg       0.97      0.98      0.97     10000
#
# Accuracy: 0.979

# %%
X_train_raw, X_val, y_train_raw, y_val, val_preds = mlp_improved(ff_inputs, labels, 4)
# Out:
# Epoch 1/200
# C:\Users\Maria\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9444 - loss: 0.4222 - val_accuracy: 0.9821 - val_loss: 0.0986
# Epoch 2/200
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.0833 - val_accuracy: 0.9822 - val_loss: 0.0700
# Epoch 3/200
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9815 - loss: 0.0672 - val_accuracy: 0.9821 - val_loss: 0.0620
# Epoch 4/200
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9815 - loss: 0.0617 - val_accuracy: 0.9822 - val_loss: 0.0588
# Epoch 5/200
# ...

# %%
X_train_raw_sm, X_val_sm, y_train_raw_sm, y_val_sm, val_pred_sm = mlp_improved_smote(ff_inputs, labels, 4)
# Out:
# C:\Users\Maria\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7195 - loss: 0.6720 - val_accuracy: 0.9313 - val_loss: 0.1868
# Epoch 2/200
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7650 - loss: 0.4658 - val_accuracy: 0.9426 - val_loss: 0.1790
# Epoch 3/200
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7679 - loss: 0.4573 - val_accuracy: 0.9445 - val_loss: 0.1760
# Epoch 4/200
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7677 - loss: 0.4548 - val_accuracy: 0.9445 - val_loss: 0.1781
# Epoch 5/200
# ...

# %%
kde_plt = sns.displot(x=ff_inputs[0], hue=labels, kind="kde", palette=sns.color_palette("hls", 4))
kde_plt.savefig("ff_kde.png")

# %%
rf_prob = RandomForestClassifier(random_state=42)
rf_prob.fit(X_val, (val_preds ==  y_val).astype(int))
# Out:
# RandomForestClassifier(random_state=42)

# %%
prob_correct = rf_prob.predict_proba(X_val)[:,1]

# %%
plt.figure(figsize=(6,4))
plt.scatter(
    X_val.iloc[:,0],
    prob_correct,
    alpha = 0.5,
    s = 2
)
plt.xlabel("Forest Density")
plt.ylabel("P(Model correct | X)")
plt.title("Probability of Correct Classification Across Input Space")
plt.savefig("misclass_ff.png")
plt.show()
